# %% [markdown]
# # Chapter 1 — Python Basics
#
# This notebook corresponds to Week 1 of *Applied Machine Learning*. It introduces basic Python operations, loops, functions, mathematical functions, and random numbers. The book example also discusses the USDA Section 502 borrower dataset.

# %%
a = 2 + 3 + 5
b = 66 - 3 - (-4)
c = 32 * 3
d = 2**3
e = 43 / 3
f = 32 // 3
g = 44 % 3
i = 44 % 3

print(e)
print(f)
print(g)

# %% [markdown]
# Book results: `14.333333333333334`, `10`, and `2`.

# %%
for x in range(0, 30, 6):
    print(x)

# %%
def myfirstfunction(x):
    y = x**3 + 3*x + 20
    print(y)

myfirstfunction(20)

# %% [markdown]
# Book result: `8080`.

# %%
import math

print(math.exp(2))
print(math.log(2))
print(math.sqrt(10))

# %% [markdown]
# Book results: `7.38905609893065`, `0.6931471805599453`, and `3.1622776601683795`.

# %%
from random import randrange

for x in range(0, 3):
    print(randrange(10))

# %% [markdown]
# The book shows `2`, `3`, and `2` for one run. Because no random seed is set in the original example, new results can differ.
